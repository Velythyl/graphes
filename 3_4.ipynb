# %%
G = graphs.CycleGraph(3)
H = graphs.BrinkmannGraph()

# %%
G.plot()
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
H.plot()
# Out:
# Graphics object consisting of 64 graphics primitives

# %%
not G.has_homomorphism_to(H) and not H.has_homomorphism_to(G)
# Out:
# True
